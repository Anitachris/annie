# %% [markdown]
# # CASE STUDY ON CORRELTION AND REGRESSION

# %% [markdown]
# ## READING THE DATA

# %%
import pandas as pd
df=pd.read_csv('Add_sales_data_2018 (1).csv')
df
# Out:
#            Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0    2018-10-08              208.00              222.25              206.85
# 1    2018-10-05              217.00              218.60              205.90
# 2    2018-10-04              223.50              227.80              216.15
# 3    2018-10-03              230.00              237.50              225.75
# 4    2018-10-01              234.55              234.60              221.05
# ..          ...                 ...                 ...                 ...
# 200  2017-12-14              288.00              288.25              279.20
# 201  2017-12-13              290.00              292.50              282.20
# 202  2017-12-12              298.60              298.60              286.65
# 203  2017-12-11              290.00              299.55              285.90
# 204  2017-12-08              287.55              289.90              285.05
#
# ...

# %% [markdown]
# ## CHECKING FOR NULL VALUES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  205 non-null    object
#  1   Add1(in Thousands)    205 non-null    float64
#  2   Add2(in Thousands)    205 non-null    float64
#  3   Add3(in Thousands)    205 non-null    float64
#  4   Add4(in Thousands)    205 non-null    float64
#  5   Add5(in Thousands)    205 non-null    float64
#  6   Profit(in Thousands)  205 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 11.3+ KB

# %% [markdown]
# ## CHECKING THE RELATIONSHIP BETWEEN PRICE SPENT ON ADDS AND PROFIT

# %% [markdown]
# ### Plotting scatter plots of various adds and profit

# %%
fig,ax=plt.subplots(5,figsize=(30,30))
ax[0].scatter(x=df['Add1(in Thousands)'],y=df['Profit(in Thousands)'])
ax[0].set_xlabel("Add1")
ax[0].set_ylabel("Profit")

ax[1].scatter(x=df['Add2(in Thousands)'],y=df['Profit(in Thousands)'])
ax[1].set_xlabel("Add2")
ax[1].set_ylabel("Profit")

ax[2].scatter(x=df['Add3(in Thousands)'],y=df['Profit(in Thousands)'])
ax[2].set_xlabel("Add3")
ax[2].set_ylabel("Profit")

ax[3].scatter(x=df['Add4(in Thousands)'],y=df['Profit(in Thousands)'])
ax[3].set_xlabel("Add4")
ax[3].set_ylabel("Profit")

ax[4].scatter(x=df['Add5(in Thousands)'],y=df['Profit(in Thousands)'])
ax[4].set_xlabel("Add5")
ax[4].set_ylabel("Profit")

plt.show()

# %% [markdown]
# **INSIGHTS
# 1 .There is high positive correlation between the amount spent on advertisements and the  profit .

# %% [markdown]
# # Preparing the correlation matrix

# %%
import seaborn as sns 
corrmatrix=df.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=0.7,vmax=0.8,annot=True,linewidth=0.2,cmap='RdYlGn')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Insights
# - There is high positive correlation between all the variables

# %% [markdown]
# # Preparing the regression model

# %%
y=df['Profit(in Thousands)']
x=df.drop(['Date','Profit(in Thousands)'],axis=1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.25)

# %%
from sklearn import linear_model
lr=linear_model.LinearRegression()

# %%
model=lr.fit(x_train,y_train)

# %%
predictions=model.predict(x_test)

# %%
print(y_test)
# Out:
# 15     4152.066
# 9      4446.441
# 100    5131.898
# 132    4907.560
# 68     5004.282
# 95     4623.793
# 159    5384.175
# 162    5328.025
# 147    5175.051
# 182    5956.323
# 191    5780.799
# 164    4997.719
# 65     5075.858
# 175    5784.540
# 73     4936.120
# 152    5065.652
# 18     4190.965
# 82     5034.726
# 86     5015.536
# 143    5134.657
# 60     5145.131
# 101    5421.940
# 98     4569.293
# 30     4598.292
# 25     4436.321
# 16     4175.677
# 168    5616.791
# 195    5667.250
# 97     4648.834
# 194    5717.838
# 67     5001.615
# 120    5182.368
# 154    5017.503
# 202    5545.013
# 79     5013.207
# 69     5030.451
# 145    5108.626
# 55     4760.877
# 45     4606.340
# 84     4925.861
# 146    5250.788
# 66     5038.222
# 111    5491.792
# 153    5019.997
# 96     4647.356
# 38     4486.380
# 24     4435.174
# 139    5300.437
# 112    5425.190
# 29     4482.183
# 19     4193.095
# 178    6062.457
# Name: Profit(in Thousands), dtype: float64

# %%
print(predictions)
# Out:
# [4152.066 4446.441 5131.898 4907.56  5004.282 4623.793 5384.175 5328.025
#  5175.051 5956.323 5780.799 4997.719 5075.858 5784.54  4936.12  5065.652
#  4190.965 5034.726 5015.536 5134.657 5145.131 5421.94  4569.293 4598.292
#  4436.321 4175.677 5616.791 5667.25  4648.834 5717.838 5001.615 5182.368
#  5017.503 5545.013 5013.207 5030.451 5108.626 4760.877 4606.34  4925.861
#  5250.788 5038.222 5491.792 5019.997 4647.356 4486.38  4435.174 5300.437
#  5425.19  4482.183 4193.095 6062.457]

# %% [markdown]
# ### Calculating MSE value

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:\n',mean_squared_error(y_test,predictions))
# Out:
# MSE is:
#  6.362927788869444e-25

# %%
model.intercept_
# Out:
# 9.094947017729282e-13

# %%
model.coef_
# Out:
# array([ 1.  , 12.38,  3.5 ,  1.  ,  0.9 ])

# %% [markdown]
# # Predicting the profit

# %%
make_pred=[[290,312,309,298,320]]
model.predict(make_pred).item()
# Out:
# 5820.060000000001

# %% [markdown]
# **   The profit is 5820
